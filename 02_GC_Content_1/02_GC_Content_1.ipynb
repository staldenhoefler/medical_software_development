# %%
GIVEN_STRING='HhadhfölGGGGCCCC'

# %%
counter=0
for c in GIVEN_STRING:
    if c == 'G' or c == 'C':
      counter+=1
      
print(f'Answer: {counter/len(GIVEN_STRING)*100}%')
# Out:
# Answer: 50.0%
